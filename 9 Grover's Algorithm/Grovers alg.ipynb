# %%
N = 16

# %%
from math import ceil,log2
n = ceil(log2(N))

# %%
n
# Out:
# 4

# %%
from random import randint
winner_index = randint(0,N-1)

# %%
winner_index
# Out:
# 3

# %%
winner_state = bin(winner_index)[2:].zfill(n)

# %%
winner_state
# Out:
# '0011'

# %%
from qiskit import QuantumCircuit
qc = QuantumCircuit(n,n)
qc.draw('mpl')

# %%
for i in range(n):
    qc.h(i)
qc.barrier()
qc.draw('mpl')

# %%
def Householder():
    import numpy as np
    Relf = np.identity(N)
    Relf[winner_index,winner_index]=-1
    from qiskit.quantum_info import Operator
    Refl_Op = Operator(Relf)
    n_qubits = []
    for i in range(n):
        n_qubits.append(i)
    qc.unitary(Refl_Op, qubits = n_qubits, label ='Uw')
    qc.barrier()
    return qc

# %%
Householder()

# %%
qc.draw('mpl')

# %%
qc.decompose().draw('mpl')

# %%
def Diffucion():
    for i in range(n):
        qc.x(i)
        qc.h(i)
    qc.h(0)
    controls = []
    for i in range(1,n):
        controls.append(i)
    qc.mct(controls,0)
    qc.h(0)
    qc.barrier()
    for i in range(n):
        qc.x(i)
        qc.h(i)
    qc.barrier()
    return qc

# %%
Diffucion()

# %%
qc.draw('mpl')

# %%
from math import asin,sqrt,pi
theta = asin(1/sqrt(N))
t = ceil(pi/(4*theta)-0.5)

# %%
t
# Out:
# 3

# %%
for i in range(t-1):
    Householder()
    Diffucion()
qc.draw('mpl')

# %%
for i in range(n):
    qc.measure(i,i)
qc.draw('mpl')

# %%
from qiskit.providers.aer import QasmSimulator
from qiskit import transpile
backend = QasmSimulator()
qc_compiled = transpile(qc, backend)
job = backend.run(qc_compiled, shots=10)
result = job.result()
counts = result.get_counts()
from qiskit.visualization import plot_histogram
plot_histogram(counts)

# %%
from qiskit.test.mock import FakeMontreal
device_simulator = FakeMontreal()

# %%
from qiskit.visualization import plot_error_map
plot_error_map(device_simulator)

# %%
qc2 = transpile(qc,device_simulator)
qc2.draw('mpl')

# %%
from qiskit.visualization import plot_circuit_layout
plot_circuit_layout(qc2,device_simulator)

# %%
job = device_simulator.run(qc2, shots=10)
result = job.result()
counts = result.get_counts()
from qiskit.visualization import plot_histogram
plot_histogram(counts)

# %%
qc2.depth()
# Out:
# 244
